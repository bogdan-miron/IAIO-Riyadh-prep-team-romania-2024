# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/content/melb_data.csv')

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df['Suburb'].unique()
# Out:
# array(['Abbotsford', 'Airport West', 'Albert Park', 'Alphington',
#        'Altona', 'Altona North', 'Armadale', 'Ascot Vale', 'Ashburton',
#        'Ashwood', 'Avondale Heights', 'Balaclava', 'Balwyn',
#        'Balwyn North', 'Bentleigh', 'Bentleigh East', 'Box Hill',
#        'Braybrook', 'Brighton', 'Brighton East', 'Brunswick',
#        'Brunswick West', 'Bulleen', 'Burwood', 'Camberwell', 'Canterbury',
#        'Carlton North', 'Carnegie', 'Caulfield', 'Caulfield North',
#        'Caulfield South', 'Chadstone', 'Clifton Hill', 'Coburg',
#        'Coburg North', 'Collingwood', 'Doncaster', 'Eaglemont',
#        'Elsternwick', 'Elwood', 'Essendon', 'Essendon North', 'Fairfield',
#        'Fitzroy', 'Fitzroy North', 'Flemington', 'Footscray', 'Glen Iris',
#        'Glenroy', 'Gowanbrae', 'Hadfield', 'Hampton', 'Hampton East',
#        'Hawthorn', 'Heidelberg Heights', 'Heidelberg West', 'Hughesdale',
#        'Ivanhoe', 'Kealba', 'Keilor East', 'Kensington', 'Kew',
# ...

# %%
df['Suburb'].value_counts()
# Out:
# Suburb
# Reservoir         359
# Richmond          260
# Bentleigh East    249
# Preston           239
# Brunswick         222
#                  ...
# Sandhurst           1
# Bullengarook        1
# Croydon South       1
# Montrose            1
# Monbulk             1
# Name: count, Length: 314, dtype: int64

# %%
df.loc[df['Suburb'] == 'Preston', 'Price'].mean()
# Out:
# 902800.8368200837

# %%
suburb_prices = df.groupby('Suburb')['Price'].mean() # Calculate the mean price for each suburb, target encoding
df['Suburb_encoded'] = df['Suburb'].map(suburb_prices) # Apply the target encoding to the 'Suburb' column

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df.drop(columns = ['Suburb'], inplace = True)

# %%
df
# Out:
#                 Address  Rooms Type      Price Method   SellerG        Date  \
# 0          85 Turner St      2    h  1480000.0      S    Biggin   3/12/2016
# 1       25 Bloomburg St      2    h  1035000.0      S    Biggin   4/02/2016
# 2          5 Charles St      3    h  1465000.0     SP    Biggin   4/03/2017
# 3      40 Federation La      3    h   850000.0     PI    Biggin   4/03/2017
# 4           55a Park St      4    h  1600000.0     VB    Nelson   4/06/2016
# ...                 ...    ...  ...        ...    ...       ...         ...
# 13575      12 Strada Cr      4    h  1245000.0      S     Barry  26/08/2017
# 13576     77 Merrett Dr      3    h  1031000.0     SP  Williams  26/08/2017
# 13577       83 Power St      3    h  1170000.0      S     Raine  26/08/2017
# 13578      96 Verdon St      4    h  2500000.0     PI   Sweeney  26/08/2017
# 13579        6 Agnes St      4    h  1285000.0     SP   Village  26/08/2017
#
# ...

# %%
df['Address'].value_counts()
# Out:
# Address
# 36 Aberfeldie St    3
# 2 Bruce St          3
# 5 Charles St        3
# 53 William St       3
# 14 Arthur St        3
#                    ..
# 16 Alleford St      1
# 2/1073 Centre Rd    1
# 14 Columbia St      1
# 21 Hardy Ct         1
# 6 Agnes St          1
# Name: count, Length: 13378, dtype: int64

# %%
address_counts = df['Address'].value_counts()
df['Address_encoded'] = df['Address'].map(address_counts)

# %%
df
# Out:
#                 Address  Rooms Type      Price Method   SellerG        Date  \
# 0          85 Turner St      2    h  1480000.0      S    Biggin   3/12/2016
# 1       25 Bloomburg St      2    h  1035000.0      S    Biggin   4/02/2016
# 2          5 Charles St      3    h  1465000.0     SP    Biggin   4/03/2017
# 3      40 Federation La      3    h   850000.0     PI    Biggin   4/03/2017
# 4           55a Park St      4    h  1600000.0     VB    Nelson   4/06/2016
# ...                 ...    ...  ...        ...    ...       ...         ...
# 13575      12 Strada Cr      4    h  1245000.0      S     Barry  26/08/2017
# 13576     77 Merrett Dr      3    h  1031000.0     SP  Williams  26/08/2017
# 13577       83 Power St      3    h  1170000.0      S     Raine  26/08/2017
# 13578      96 Verdon St      4    h  2500000.0     PI   Sweeney  26/08/2017
# 13579        6 Agnes St      4    h  1285000.0     SP   Village  26/08/2017
#
# ...

# %%
df.drop(columns = ['Address'], inplace = True)

# %%
df
# Out:
#        Rooms Type      Price Method   SellerG        Date  Distance  Postcode  \
# 0          2    h  1480000.0      S    Biggin   3/12/2016       2.5    3067.0
# 1          2    h  1035000.0      S    Biggin   4/02/2016       2.5    3067.0
# 2          3    h  1465000.0     SP    Biggin   4/03/2017       2.5    3067.0
# 3          3    h   850000.0     PI    Biggin   4/03/2017       2.5    3067.0
# 4          4    h  1600000.0     VB    Nelson   4/06/2016       2.5    3067.0
# ...      ...  ...        ...    ...       ...         ...       ...       ...
# 13575      4    h  1245000.0      S     Barry  26/08/2017      16.7    3150.0
# 13576      3    h  1031000.0     SP  Williams  26/08/2017       6.8    3016.0
# 13577      3    h  1170000.0      S     Raine  26/08/2017       6.8    3016.0
# 13578      4    h  2500000.0     PI   Sweeney  26/08/2017       6.8    3016.0
# 13579      4    h  1285000.0     SP   Village  26/08/2017       6.3    3013.0
#
# ...

# %%
type(df['Rooms'][1])
# Out:
# numpy.int64

# %%
df['Type'].value_counts()
# Out:
# Type
# h    9449
# u    3017
# t    1114
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns = ['Type']) # One hot encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rooms            13580 non-null  int64
#  1   Price            13580 non-null  float64
#  2   Method           13580 non-null  object
#  3   SellerG          13580 non-null  object
#  4   Date             13580 non-null  object
#  5   Distance         13580 non-null  float64
#  6   Postcode         13580 non-null  float64
#  7   Bedroom2         13580 non-null  float64
#  8   Bathroom         13580 non-null  float64
#  9   Car              13518 non-null  float64
#  10  Landsize         13580 non-null  float64
#  11  BuildingArea     7130 non-null   float64
#  12  YearBuilt        8205 non-null   float64
#  13  CouncilArea      12211 non-null  object
#  14  Lattitude        13580 non-null  float64
#  15  Longtitude       13580 non-null  float64
# ...

# %%
df
# Out:
#        Rooms      Price Method   SellerG        Date  Distance  Postcode  \
# 0          2  1480000.0      S    Biggin   3/12/2016       2.5    3067.0
# 1          2  1035000.0      S    Biggin   4/02/2016       2.5    3067.0
# 2          3  1465000.0     SP    Biggin   4/03/2017       2.5    3067.0
# 3          3   850000.0     PI    Biggin   4/03/2017       2.5    3067.0
# 4          4  1600000.0     VB    Nelson   4/06/2016       2.5    3067.0
# ...      ...        ...    ...       ...         ...       ...       ...
# 13575      4  1245000.0      S     Barry  26/08/2017      16.7    3150.0
# 13576      3  1031000.0     SP  Williams  26/08/2017       6.8    3016.0
# 13577      3  1170000.0      S     Raine  26/08/2017       6.8    3016.0
# 13578      4  2500000.0     PI   Sweeney  26/08/2017       6.8    3016.0
# 13579      4  1285000.0     SP   Village  26/08/2017       6.3    3013.0
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt CouncilArea  \
# ...

# %%
df['Method'].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
# One hot encoding for 'Method'
df = pd.get_dummies(df, columns = ['Method'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rooms            13580 non-null  int64
#  1   Price            13580 non-null  float64
#  2   SellerG          13580 non-null  object
#  3   Date             13580 non-null  object
#  4   Distance         13580 non-null  float64
#  5   Postcode         13580 non-null  float64
#  6   Bedroom2         13580 non-null  float64
#  7   Bathroom         13580 non-null  float64
#  8   Car              13518 non-null  float64
#  9   Landsize         13580 non-null  float64
#  10  BuildingArea     7130 non-null   float64
#  11  YearBuilt        8205 non-null   float64
#  12  CouncilArea      12211 non-null  object
#  13  Lattitude        13580 non-null  float64
#  14  Longtitude       13580 non-null  float64
#  15  Regionname       13580 non-null  object
# ...

# %%
df
# Out:
#        Rooms      Price   SellerG        Date  Distance  Postcode  Bedroom2  \
# 0          2  1480000.0    Biggin   3/12/2016       2.5    3067.0       2.0
# 1          2  1035000.0    Biggin   4/02/2016       2.5    3067.0       2.0
# 2          3  1465000.0    Biggin   4/03/2017       2.5    3067.0       3.0
# 3          3   850000.0    Biggin   4/03/2017       2.5    3067.0       3.0
# 4          4  1600000.0    Nelson   4/06/2016       2.5    3067.0       3.0
# ...      ...        ...       ...         ...       ...       ...       ...
# 13575      4  1245000.0     Barry  26/08/2017      16.7    3150.0       4.0
# 13576      3  1031000.0  Williams  26/08/2017       6.8    3016.0       3.0
# 13577      3  1170000.0     Raine  26/08/2017       6.8    3016.0       3.0
# 13578      4  2500000.0   Sweeney  26/08/2017       6.8    3016.0       4.0
# 13579      4  1285000.0   Village  26/08/2017       6.3    3013.0       4.0
#
# ...

# %%
df['SellerG'].unique()
# Out:
# array(['Biggin', 'Nelson', 'Jellis', 'Greg', 'LITTLE', 'Collins', 'Kay',
#        'Beller', 'Marshall', 'Brad', 'Maddison', 'Barry', 'Considine',
#        'Rendina', 'Propertyau', 'McDonald', 'Prof.', 'Harcourts',
#        'hockingstuart', 'Thomson', 'Buxton', 'RT', "Sotheby's", 'Cayzer',
#        'Chisholm', 'Brace', 'Miles', 'McGrath', 'Love', 'Barlow',
#        'Sweeney', 'Village', 'Jas', 'Gunn&Co', 'Burnham', 'Williams',
#        'Compton', 'FN', 'Raine&Horne', 'Hunter', 'Noel', 'Hodges', 'Ray',
#        'Gary', 'Fletchers', 'Woodards', 'Raine', 'Walshe', 'Alexkarbon',
#        'Weda', 'Frank', 'Stockdale', 'Tim', 'Purplebricks', 'Moonee',
#        'HAR', 'Edward', 'Philip', 'RW', 'North', 'Ascend', 'Christopher',
#        'Mandy', 'R&H', 'Fletchers/One', 'Assisi', 'One', "O'Brien", 'C21',
#        'Bayside', 'Paul', 'First', 'Matthew', 'Anderson', 'Nick',
#        'Lindellas', 'Allens', 'Bells', 'Trimson', 'Douglas', 'YPA', 'GL',
# ...

# %%
df['SellerG'].value_counts()
# Out:
# SellerG
# Nelson           1565
# Jellis           1316
# hockingstuart    1167
# Barry            1011
# Ray               701
#                  ...
# Prowse              1
# Luxe                1
# Zahn                1
# Homes               1
# Point               1
# Name: count, Length: 268, dtype: int64

# %%
# Label encoding the 'SellerG'
label_encoder = LabelEncoder()
df['SellerG_encoded'] = label_encoder.fit_transform(df['SellerG'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rooms            13580 non-null  int64
#  1   Price            13580 non-null  float64
#  2   SellerG          13580 non-null  object
#  3   Date             13580 non-null  object
#  4   Distance         13580 non-null  float64
#  5   Postcode         13580 non-null  float64
#  6   Bedroom2         13580 non-null  float64
#  7   Bathroom         13580 non-null  float64
#  8   Car              13518 non-null  float64
#  9   Landsize         13580 non-null  float64
#  10  BuildingArea     7130 non-null   float64
#  11  YearBuilt        8205 non-null   float64
#  12  CouncilArea      12211 non-null  object
#  13  Lattitude        13580 non-null  float64
#  14  Longtitude       13580 non-null  float64
#  15  Regionname       13580 non-null  object
# ...

# %%
df.drop(columns = ['SellerG'], inplace = True)

# %%
df
# Out:
#        Rooms      Price        Date  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2  1480000.0   3/12/2016       2.5    3067.0       2.0       1.0
# 1          2  1035000.0   4/02/2016       2.5    3067.0       2.0       1.0
# 2          3  1465000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 3          3   850000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 4          4  1600000.0   4/06/2016       2.5    3067.0       3.0       1.0
# ...      ...        ...         ...       ...       ...       ...       ...
# 13575      4  1245000.0  26/08/2017      16.7    3150.0       4.0       2.0
# 13576      3  1031000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13577      3  1170000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13578      4  2500000.0  26/08/2017       6.8    3016.0       4.0       1.0
# 13579      4  1285000.0  26/08/2017       6.3    3013.0       4.0       1.0
#
# ...

# %%
df['Date'][0]
# Out:
# '3/12/2016'

# %%
df['Date'][0][-2:]
df['Date_encoded'] = 0
df
# Out:
#        Rooms      Price        Date  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2  1480000.0   3/12/2016       2.5    3067.0       2.0       1.0
# 1          2  1035000.0   4/02/2016       2.5    3067.0       2.0       1.0
# 2          3  1465000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 3          3   850000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 4          4  1600000.0   4/06/2016       2.5    3067.0       3.0       1.0
# ...      ...        ...         ...       ...       ...       ...       ...
# 13575      4  1245000.0  26/08/2017      16.7    3150.0       4.0       2.0
# 13576      3  1031000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13577      3  1170000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13578      4  2500000.0  26/08/2017       6.8    3016.0       4.0       1.0
# 13579      4  1285000.0  26/08/2017       6.3    3013.0       4.0       1.0
#
# ...

# %%
for i in range(0, 13580):
  df['Date_encoded'][i] = int(df['Date'][i][-2:])
# Out:
# Datele de ieșire de afișat au fost trunchiate la ultimele 5000 linii.
# <ipython-input-31-5f7a0a1eb92a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date_encoded'][i] = int(df['Date'][i][-2:])
# <ipython-input-31-5f7a0a1eb92a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date_encoded'][i] = int(df['Date'][i][-2:])
# <ipython-input-31-5f7a0a1eb92a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#        Rooms      Price        Date  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2  1480000.0   3/12/2016       2.5    3067.0       2.0       1.0
# 1          2  1035000.0   4/02/2016       2.5    3067.0       2.0       1.0
# 2          3  1465000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 3          3   850000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 4          4  1600000.0   4/06/2016       2.5    3067.0       3.0       1.0
# ...      ...        ...         ...       ...       ...       ...       ...
# 13575      4  1245000.0  26/08/2017      16.7    3150.0       4.0       2.0
# 13576      3  1031000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13577      3  1170000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13578      4  2500000.0  26/08/2017       6.8    3016.0       4.0       1.0
# 13579      4  1285000.0  26/08/2017       6.3    3013.0       4.0       1.0
#
# ...

# %%
df['Date_encoded'].unique()
# Out:
# array([16, 17])

# %%
df
# Out:
#        Rooms      Price        Date  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2  1480000.0   3/12/2016       2.5    3067.0       2.0       1.0
# 1          2  1035000.0   4/02/2016       2.5    3067.0       2.0       1.0
# 2          3  1465000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 3          3   850000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 4          4  1600000.0   4/06/2016       2.5    3067.0       3.0       1.0
# ...      ...        ...         ...       ...       ...       ...       ...
# 13575      4  1245000.0  26/08/2017      16.7    3150.0       4.0       2.0
# 13576      3  1031000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13577      3  1170000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13578      4  2500000.0  26/08/2017       6.8    3016.0       4.0       1.0
# 13579      4  1285000.0  26/08/2017       6.3    3013.0       4.0       1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rooms            13580 non-null  int64
#  1   Price            13580 non-null  float64
#  2   Date             13580 non-null  object
#  3   Distance         13580 non-null  float64
#  4   Postcode         13580 non-null  float64
#  5   Bedroom2         13580 non-null  float64
#  6   Bathroom         13580 non-null  float64
#  7   Car              13518 non-null  float64
#  8   Landsize         13580 non-null  float64
#  9   BuildingArea     7130 non-null   float64
#  10  YearBuilt        8205 non-null   float64
#  11  CouncilArea      12211 non-null  object
#  12  Lattitude        13580 non-null  float64
#  13  Longtitude       13580 non-null  float64
#  14  Regionname       13580 non-null  object
#  15  Propertycount    13580 non-null  float64
# ...

# %%
df['Building_Area_encoded'] = df['BuildingArea'] # Encoding using the mean of the data
df.loc[df['BuildingArea'].isna(), 'Building_Area_encoded'] = df['BuildingArea'].mean()
df
# Out:
#        Rooms      Price        Date  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2  1480000.0   3/12/2016       2.5    3067.0       2.0       1.0
# 1          2  1035000.0   4/02/2016       2.5    3067.0       2.0       1.0
# 2          3  1465000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 3          3   850000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 4          4  1600000.0   4/06/2016       2.5    3067.0       3.0       1.0
# ...      ...        ...         ...       ...       ...       ...       ...
# 13575      4  1245000.0  26/08/2017      16.7    3150.0       4.0       2.0
# 13576      3  1031000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13577      3  1170000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13578      4  2500000.0  26/08/2017       6.8    3016.0       4.0       1.0
# 13579      4  1285000.0  26/08/2017       6.3    3013.0       4.0       1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rooms                  13580 non-null  int64
#  1   Price                  13580 non-null  float64
#  2   Date                   13580 non-null  object
#  3   Distance               13580 non-null  float64
#  4   Postcode               13580 non-null  float64
#  5   Bedroom2               13580 non-null  float64
#  6   Bathroom               13580 non-null  float64
#  7   Car                    13518 non-null  float64
#  8   Landsize               13580 non-null  float64
#  9   BuildingArea           7130 non-null   float64
#  10  YearBuilt              8205 non-null   float64
#  11  CouncilArea            12211 non-null  object
#  12  Lattitude              13580 non-null  float64
#  13  Longtitude             13580 non-null  float64
# ...

# %%
df['YearBuilt'].value_counts()
# Out:
# YearBuilt
# 1970.0    866
# 1960.0    725
# 1950.0    580
# 1900.0    341
# 1980.0    338
#          ...
# 1897.0      1
# 1933.0      1
# 1830.0      1
# 1901.0      1
# 1857.0      1
# Name: count, Length: 144, dtype: int64

# %%
df['YearBuilt_encoded'] = df['YearBuilt'] # Encoding using the mean of the data
df.loc[df['YearBuilt'].isna(), 'YearBuilt_encoded'] = df['YearBuilt'].mean()
df['Car_encoded'] = df['Car'] # Encoding using the mean of the data
df.loc[df['Car'].isna(), 'Car_encoded'] = df['Car'].mean()
df
# Out:
#        Rooms      Price        Date  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2  1480000.0   3/12/2016       2.5    3067.0       2.0       1.0
# 1          2  1035000.0   4/02/2016       2.5    3067.0       2.0       1.0
# 2          3  1465000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 3          3   850000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 4          4  1600000.0   4/06/2016       2.5    3067.0       3.0       1.0
# ...      ...        ...         ...       ...       ...       ...       ...
# 13575      4  1245000.0  26/08/2017      16.7    3150.0       4.0       2.0
# 13576      3  1031000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13577      3  1170000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13578      4  2500000.0  26/08/2017       6.8    3016.0       4.0       1.0
# 13579      4  1285000.0  26/08/2017       6.3    3013.0       4.0       1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rooms                  13580 non-null  int64
#  1   Price                  13580 non-null  float64
#  2   Date                   13580 non-null  object
#  3   Distance               13580 non-null  float64
#  4   Postcode               13580 non-null  float64
#  5   Bedroom2               13580 non-null  float64
#  6   Bathroom               13580 non-null  float64
#  7   Car                    13518 non-null  float64
#  8   Landsize               13580 non-null  float64
#  9   BuildingArea           7130 non-null   float64
#  10  YearBuilt              8205 non-null   float64
#  11  CouncilArea            12211 non-null  object
#  12  Lattitude              13580 non-null  float64
#  13  Longtitude             13580 non-null  float64
# ...

# %%
df['CouncilArea'].unique()
# Out:
# array(['Yarra', 'Moonee Valley', 'Port Phillip', 'Darebin', 'Hobsons Bay',
#        'Stonnington', 'Boroondara', 'Monash', 'Glen Eira', 'Whitehorse',
#        'Maribyrnong', 'Bayside', 'Moreland', 'Manningham', 'Banyule',
#        'Melbourne', 'Kingston', 'Brimbank', 'Hume', nan, 'Knox',
#        'Maroondah', 'Casey', 'Melton', 'Greater Dandenong', 'Nillumbik',
#        'Whittlesea', 'Frankston', 'Macedon Ranges', 'Yarra Ranges',
#        'Wyndham', 'Cardinia', 'Unavailable', 'Moorabool'], dtype=object)

# %%
# feature engineer using label encoding
df['CouncilArea_encoded'] = label_encoder.fit_transform(df['CouncilArea'])

# %%
df
# Out:
#        Rooms      Price        Date  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2  1480000.0   3/12/2016       2.5    3067.0       2.0       1.0
# 1          2  1035000.0   4/02/2016       2.5    3067.0       2.0       1.0
# 2          3  1465000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 3          3   850000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 4          4  1600000.0   4/06/2016       2.5    3067.0       3.0       1.0
# ...      ...        ...         ...       ...       ...       ...       ...
# 13575      4  1245000.0  26/08/2017      16.7    3150.0       4.0       2.0
# 13576      3  1031000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13577      3  1170000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13578      4  2500000.0  26/08/2017       6.8    3016.0       4.0       1.0
# 13579      4  1285000.0  26/08/2017       6.3    3013.0       4.0       1.0
#
# ...

# %%
df['CouncilArea_encoded'].unique()
# Out:
# array([31, 21, 25,  6, 10, 26,  2, 20,  8, 28, 16,  1, 23, 15,  0, 18, 12,
#         3, 11, 33, 13, 17,  5, 19,  9, 24, 29,  7, 14, 32, 30,  4, 27, 22])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rooms                  13580 non-null  int64
#  1   Price                  13580 non-null  float64
#  2   Date                   13580 non-null  object
#  3   Distance               13580 non-null  float64
#  4   Postcode               13580 non-null  float64
#  5   Bedroom2               13580 non-null  float64
#  6   Bathroom               13580 non-null  float64
#  7   Car                    13518 non-null  float64
#  8   Landsize               13580 non-null  float64
#  9   BuildingArea           7130 non-null   float64
#  10  YearBuilt              8205 non-null   float64
#  11  CouncilArea            12211 non-null  object
#  12  Lattitude              13580 non-null  float64
#  13  Longtitude             13580 non-null  float64
# ...

# %%
df['Regionname'].unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Eastern Victoria',
#        'Northern Victoria', 'Western Victoria'], dtype=object)

# %%
df['Regionname_encoded'] = label_encoder.fit_transform(df['Regionname'])

# %%
df
# Out:
#        Rooms      Price        Date  Distance  Postcode  Bedroom2  Bathroom  \
# 0          2  1480000.0   3/12/2016       2.5    3067.0       2.0       1.0
# 1          2  1035000.0   4/02/2016       2.5    3067.0       2.0       1.0
# 2          3  1465000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 3          3   850000.0   4/03/2017       2.5    3067.0       3.0       2.0
# 4          4  1600000.0   4/06/2016       2.5    3067.0       3.0       1.0
# ...      ...        ...         ...       ...       ...       ...       ...
# 13575      4  1245000.0  26/08/2017      16.7    3150.0       4.0       2.0
# 13576      3  1031000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13577      3  1170000.0  26/08/2017       6.8    3016.0       3.0       2.0
# 13578      4  2500000.0  26/08/2017       6.8    3016.0       4.0       1.0
# 13579      4  1285000.0  26/08/2017       6.3    3013.0       4.0       1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rooms                  13580 non-null  int64
#  1   Price                  13580 non-null  float64
#  2   Date                   13580 non-null  object
#  3   Distance               13580 non-null  float64
#  4   Postcode               13580 non-null  float64
#  5   Bedroom2               13580 non-null  float64
#  6   Bathroom               13580 non-null  float64
#  7   Car                    13518 non-null  float64
#  8   Landsize               13580 non-null  float64
#  9   BuildingArea           7130 non-null   float64
#  10  YearBuilt              8205 non-null   float64
#  11  CouncilArea            12211 non-null  object
#  12  Lattitude              13580 non-null  float64
#  13  Longtitude             13580 non-null  float64
# ...

# %%
X = df[[
    'Rooms',
    'Date_encoded',
    'Distance',
    'Postcode',
    'Bedroom2',
    'Bathroom',
    'Car_encoded',
    'Landsize',
    'Building_Area_encoded',
    'YearBuilt_encoded',
    'CouncilArea_encoded',
    'Regionname_encoded',
    'Propertycount',
    'Suburb_encoded',
    'Address_encoded',
    'Type_h',
    'Type_u',
    'Type_t',
    'Method_S',
    'Method_SP',
    'Method_PI',
    'Method_VB',
    'Method_SA'

]]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rooms                  13580 non-null  int64
#  1   Date_encoded           13580 non-null  int64
#  2   Distance               13580 non-null  float64
#  3   Postcode               13580 non-null  float64
#  4   Bedroom2               13580 non-null  float64
#  5   Bathroom               13580 non-null  float64
#  6   Car_encoded            13580 non-null  float64
#  7   Landsize               13580 non-null  float64
#  8   Building_Area_encoded  13580 non-null  float64
#  9   YearBuilt_encoded      13580 non-null  float64
#  10  CouncilArea_encoded    13580 non-null  int64
#  11  Regionname_encoded     13580 non-null  int64
#  12  Propertycount          13580 non-null  float64
#  13  Suburb_encoded         13580 non-null  float64
# ...

# %%
y = df['Price']

# %%
from sklearn.model_selection import train_test_split # for spliting test and train data
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state = 1) # si aici se poate cu smote

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
# Linear Regression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Linear Regression MSE:", mse)
print(model.score(X_test, y_test))
# Out:
# Linear Regression MSE: 124516301135.73393
# 0.6852650057604268

# %%
# DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("DecisionTreeRegressor MSE:", mse)
model.score(X_test, y_test)
# Out:
# DecisionTreeRegressor MSE: 144788991011.95712
# 0.6340225188473404

# %%
# RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("RandomForestRegressor MSE:", mse)
print("RandomForestRegressor MAE:", mae)
print("RandomForestRegressor R2:", r2)
model.score(X_test, y_test)
# Out:
# RandomForestRegressor MSE: 64764033646.09932
# RandomForestRegressor MAE: 158486.12696566017
# RandomForestRegressor R2: 0.8362984763334884
# 0.8362984763334884

# %%
# Gradient Boosting Regressor
model = GradientBoostingRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("GradientBoostingRegressor MSE:", mse)
print(model.score(X_test, y_test))
# Out:
# GradientBoostingRegressor MSE: 71652041152.36037
# 0.8188879323137077

# %%
# Neural Network

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import GridSearchCV # hyperparameter tuning

# Convert input data to floating-point numbers
X_train = X_train.astype('float32')
y_train = y_train.astype('float32')
X_test = X_test.astype('float32')
y_test = y_test.astype('float32')

def create_model():
  # Define the model
  model_nn = Sequential([
      Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
      # Dropout(0.2),
      Dense(32, activation='relu'),
      Dense(1)  # Output layer
  ])

  # Compile the model
  model_nn.compile(optimizer='adam', loss='mean_squared_error')
  return model_nn

# Train the model
model_nn = create_model()
model_nn.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=2)

y_pred_nn = model_nn.predict(X_test)

# Evaluate the model
mse_nn = mean_squared_error(y_test, y_pred_nn)
rmse_nn = np.sqrt(mse_nn)
mae_nn = mean_absolute_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

# Print the metrics
print(f"Mean Squared Error (MSE): {mse_nn}")
print(f"Root Mean Squared Error (RMSE): {rmse_nn}")
print(f"Mean Absolute Error (MAE): {mae_nn}")
print(f"R-squared: {r2_nn}")

# Evaluate the model
mse_nn = model_nn.evaluate(X_test, y_test)
print(f"Neural Network MSE: {mse_nn}")
# Out:
# Epoch 1/50
# 361/361 - 2s - loss: 473555075072.0000 - val_loss: 267903664128.0000 - 2s/epoch - 6ms/step
# Epoch 2/50
# 361/361 - 1s - loss: 283588526080.0000 - val_loss: 268932612096.0000 - 1s/epoch - 4ms/step
# Epoch 3/50
# 361/361 - 1s - loss: 284252602368.0000 - val_loss: 265920872448.0000 - 1s/epoch - 4ms/step
# Epoch 4/50
# 361/361 - 1s - loss: 284543909888.0000 - val_loss: 267995037696.0000 - 665ms/epoch - 2ms/step
# Epoch 5/50
# 361/361 - 1s - loss: 284131000320.0000 - val_loss: 265753706496.0000 - 671ms/epoch - 2ms/step
# Epoch 6/50
# 361/361 - 1s - loss: 283596849152.0000 - val_loss: 265807200256.0000 - 690ms/epoch - 2ms/step
# Epoch 7/50
# 361/361 - 1s - loss: 284245590016.0000 - val_loss: 265686777856.0000 - 679ms/epoch - 2ms/step
# Epoch 8/50
# 361/361 - 1s - loss: 283817803776.0000 - val_loss: 265622274048.0000 - 602ms/epoch - 2ms/step
# Epoch 9/50
# 361/361 - 1s - loss: 284271738880.0000 - val_loss: 265731948544.0000 - 685ms/epoch - 2ms/step
# Epoch 10/50
# ...

# %%
# Hyperparameter tuning
from scikeras.wrappers import KerasRegressor # Import KerasRegressor

model_nn = KerasRegressor(model=create_model, verbose = 0)

param_grid = {
    'epochs': [50, 75],
    'batch_size': [32, 64]
}

grid = GridSearchCV(estimator=model_nn, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)
grid_result = grid.fit(X, y)

print(f"Best params: {grid_result.best_params_}")
print(f"Best MSE: {-grid_result.best_score_}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-64704687eec9> in <cell line: 2>()
#       1 # Hyperparameter tuning
# ----> 2 from scikeras.wrappers import KerasRegressor # Import KerasRegressor
#       3
#       4 model_nn = KerasRegressor(model=create_model, verbose = 0)
#       5
#
# ModuleNotFoundError: No module named 'scikeras'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install --upgrade tensorflow scikeras

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("XGBoost MSE:", mse)
print(xgb_model.score(X_test, y_test))
# Out:
# XGBoost MSE: 68473310000.0
# 0.8269226889565198

# %%
from skopt import BayesSearchCV
# hyperparameter optimisation, bayes search

bayes_search = BayesSearchCV(estimator=GradientBoostingRegressor(), search_spaces={
    'n_estimators': (50, 200),
    'learning_rate': (0.01, 1.0, 'log-uniform'),
    'max_depth': (1, 10)
}, n_iter=32, cv=3, random_state=42)

bayes_search.fit(X_train, y_train)
best_params = bayes_search.best_params_
print(best_params)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-c6e2eaa2179a> in <cell line: 10>()
#       8 }, n_iter=32, cv=3, random_state=42)
#       9
# ---> 10 bayes_search.fit(X_train, y_train)
#      11 best_params = bayes_search.best_params_
#      12 print(best_params)
#
# /usr/local/lib/python3.10/dist-packages/skopt/searchcv.py in fit(self, X, y, groups, callback, **fit_params)
#     540             )
#     541
# --> 542         super().fit(X=X, y=y, groups=groups, **fit_params)
#     543
#     544         # BaseSearchCV never ranked train scores,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
# ...

# %%
# !pip install scikit-optimize

# %%
# Transfomer approach, the data needs to be scaled
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import layers, models

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled_tf = tf.convert_to_tensor(X_train_scaled, dtype=tf.float32)
X_test_scaled_tf = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = models.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim)]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

def build_transformer_model(input_shape, embed_dim, num_heads, ff_dim, num_blocks):
    inputs = layers.Input(shape=input_shape)
    x = layers.Reshape((input_shape[0], 1))(inputs)  # Reshape to 3D
    x = layers.Dense(embed_dim)(x)
    for _ in range(num_blocks):
        x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.1)(x)
    x = layers.Dense(20, activation="relu")(x)
    x = layers.Dropout(0.1)(x)
    outputs = layers.Dense(1)(x)

    model = models.Model(inputs=inputs, outputs=outputs)
    return model

input_shape = (X_train_scaled.shape[1], 1)  # Update the input shape to include the additional dimension
embed_dim = 32
num_heads = 2
ff_dim = 32
num_blocks = 2

model = build_transformer_model(input_shape, embed_dim, num_heads, ff_dim, num_blocks)

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

# Train the model
history = model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model
loss, mae = model.evaluate(X_test_scaled, y_test)
print(f'Mean Absolute Error on test set: {mae}')
# Out:
# Epoch 1/50
# 289/289 [==============================] - 19s 40ms/step - loss: 1548924223488.0000 - mae: 1069647.0000 - val_loss: 1645676462080.0000 - val_mae: 1100265.5000
# Epoch 2/50
# 289/289 [==============================] - 9s 31ms/step - loss: 1548227575808.0000 - mae: 1069323.1250 - val_loss: 1644265865216.0000 - val_mae: 1099623.8750
# Epoch 3/50
# 289/289 [==============================] - 7s 23ms/step - loss: 1545898295296.0000 - mae: 1068231.0000 - val_loss: 1640737538048.0000 - val_mae: 1098018.3750
# Epoch 4/50
# 289/289 [==============================] - 9s 30ms/step - loss: 1541173542912.0000 - mae: 1066019.0000 - val_loss: 1634431008768.0000 - val_mae: 1095142.7500
# Epoch 5/50
# 289/289 [==============================] - 7s 24ms/step - loss: 1533493641216.0000 - mae: 1062402.8750 - val_loss: 1624885035008.0000 - val_mae: 1090775.7500
# Epoch 6/50
# ...
