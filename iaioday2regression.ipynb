# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)

root_dir = "/content/drive/My Drive/"
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/drive/MyDrive/WildBlueberryPollinationSimulationData.csv')

# %%
# !unzip '/content/drive/MyDrive/pregatire-iaio-ziua-2.zip'
# Out:
# Archive:  /content/drive/MyDrive/pregatire-iaio-ziua-2.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
df2 = pd.read_csv('/content/train.csv')

# %%
df2
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
# df = pd.concat([df1, df2])
df = df2

# %%
df2
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
df1 = df1.rename(columns = {"Row#" : "id"})

# %%
df2
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
df
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15289 entries, 0 to 15288
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            15289 non-null  int64
#  1   clonesize                     15289 non-null  float64
#  2   honeybee                      15289 non-null  float64
#  3   bumbles                       15289 non-null  float64
#  4   andrena                       15289 non-null  float64
#  5   osmia                         15289 non-null  float64
#  6   MaxOfUpperTRange              15289 non-null  float64
#  7   MinOfUpperTRange              15289 non-null  float64
#  8   AverageOfUpperTRange          15289 non-null  float64
#  9   MaxOfLowerTRange              15289 non-null  float64
#  10  MinOfLowerTRange              15289 non-null  float64
#  11  AverageOfLowerTRange          15289 non-null  float64
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
plt.figure(figsize = (10, 6))
sns.histplot(df['clonesize'], color = 'red', alpha = 0.7, kde = True, bins = 10)
# Out:
# <Axes: xlabel='clonesize', ylabel='Count'>

# %%
df['clonesize_encoded'] = df['clonesize']

# %%
df['clonesize_encoded'] = np.where((df['clonesize_encoded'] >= 0) & (df['clonesize_encoded'] <= 15), 1, df['clonesize_encoded'])

# %%
df['clonesize_encoded'] = np.where((df['clonesize_encoded'] > 15) & (df['clonesize_encoded'] <= 25), 2, df['clonesize_encoded'])

# %%
df['clonesize_encoded'] = np.where((df['clonesize_encoded'] > 25) & (df['clonesize_encoded'] <= 35), 3, df['clonesize_encoded'])

# %%
df['clonesize_encoded'] = np.where((df['clonesize_encoded'] > 35), 4, df['clonesize_encoded'])

# %%
df['clonesize_encoded'].value_counts()
# Out:
# clonesize_encoded
# 2.0    8301
# 1.0    6721
# 4.0     267
# Name: count, dtype: int64

# %%
df
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
df['honeybee'].value_counts()
# Out:
# honeybee
# 0.500     7832
# 0.250     7285
# 0.750      110
# 0.537       38
# 0.000       16
# 18.430       5
# 6.640        3
# Name: count, dtype: int64

# %%
df['total_honeybee'] = df['clonesize'] * df['honeybee']

# %%
correlation = df[['clonesize', 'honeybee', 'total_honeybee']].corr()

# %%
print(correlation)
# Out:
#                 clonesize  honeybee  total_honeybee
# clonesize        1.000000  0.304130        0.542613
# honeybee         0.304130  1.000000        0.962328
# total_honeybee   0.542613  0.962328        1.000000

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)
df['pca_density'] = pca.fit_transform(df[['honeybee', 'bumbles', 'andrena', 'osmia']])

# %%
df
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
plt.figure(figsize = (10, 6))
sns.histplot(df['AverageOfUpperTRange'], color = 'red', alpha = 0.7, kde = True, bins = 30)
# Out:
# <Axes: xlabel='AverageOfUpperTRange', ylabel='Count'>

# %%
# Binning the AverageOfUpperTRange feature
df['AverageOfUpperTRange_encoded'] = df['AverageOfUpperTRange']

# %%
bins = [0, 60, 67, 75, 80]
labels = [1, 2, 3, 4]
df['AverageOfUpperTRange_encoded'] = pd.cut(df['AverageOfUpperTRange_encoded'], bins = bins, labels = labels)

# %%
df
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
plt.figure(figsize = (10, 6))
sns.histplot(df['AverageOfLowerTRange'], color = 'red', alpha = 0.7, kde = True, bins = 30)
# Out:
# <Axes: xlabel='AverageOfLowerTRange', ylabel='Count'>

# %%
# Binning the AverageOfLowerTRange feature
df['AverageOfLowerTRange_encoded'] = df['AverageOfLowerTRange']

# %%
bins = [0, 42, 48, 52, 59]
labels = [1, 2, 3, 4]
df['AverageOfLowerTRange_encoded'] = pd.cut(df['AverageOfLowerTRange_encoded'], bins = bins, labels = labels)

# %%
df
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
plt.figure(figsize = (10, 6))
sns.histplot(df['RainingDays'], color = 'red', alpha = 0.7, kde = True, bins = 30)
# Out:
# <Axes: xlabel='RainingDays', ylabel='Count'>

# %%
# Binning the rainy days
bins = [0, 10, 20, 30, 40]
labels = [1, 2, 3, 4]
df['RainingDays_encoded'] = pd.cut(df['RainingDays'], bins = bins, labels = labels)

# %%
df
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
df['fruitset'].min()
# Out:
# 0.192731658

# %%
df['fruitset_encoded'] = round(df['fruitset'], 3)

# %%
df['fruitmass_encoded'] = round(df['fruitmass'], 3)

# %%
plt.figure(figsize = (10, 6))
sns.histplot(df['seeds'], color = 'red', alpha = 0.7, kde = True, bins = 30)
# Out:
# <Axes: xlabel='seeds', ylabel='Count'>

# %%
df['seeds_encoded'] = round(df['seeds'], 3)

# %%
df
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
df['yield_encoded'] = round(df['yield'], 3)

# %%
df
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
X = df[[
    'seeds_encoded',
    'fruitmass_encoded',
    'fruitset_encoded',
    'AverageOfLowerTRange_encoded',
    'AverageOfUpperTRange_encoded',
    'pca_density',
    'clonesize_encoded',
    'AverageRainingDays'
]]

# %%
y = df['yield_encoded']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15289 entries, 0 to 15288
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   seeds_encoded                 15289 non-null  float64
#  1   fruitmass_encoded             15289 non-null  float64
#  2   fruitset_encoded              15289 non-null  float64
#  3   AverageOfLowerTRange_encoded  15289 non-null  category
#  4   AverageOfUpperTRange_encoded  15289 non-null  category
#  5   pca_density                   15289 non-null  float64
#  6   clonesize_encoded             15289 non-null  float64
#  7   AverageRainingDays            15289 non-null  float64
# dtypes: category(2), float64(6)
# memory usage: 747.1 KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error
import xgboost as xgb
from sklearn.model_selection import cross_val_score

from sklearn.svm import SVR

# %%
# RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print("RandomForestRegressor MAE:", mae)
model.score(X_test, y_test)
# Out:
# RandomForestRegressor MAE: 361.879003471634
# 0.8137539479301519

# %%
# Gradient Boosting Regressor
model = GradientBoostingRegressor(
    n_estimators = 70,
    learning_rate = 0.1,
    max_depth = 5,
    min_samples_split = 4,
    min_samples_leaf = 4,
    subsample = 0.6,
    # max_features = None,
)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print("GradientBoostingRegressor MAE:", mae)
model.score(X_test, y_test)
# Out:
# GradientBoostingRegressor MAE: 347.50128765091756
# 0.8279178483170249

# %%
# XGB Regressor
model = xgb.XGBRegressor(enable_categorical = True)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print("XGBRegressor MAE:", mae)
model.score(X_test, y_test)
# Out:
# XGBRegressor MAE: 363.22873800624586
# 0.8152481901083298

# %%
df_testing = pd.read_csv('/content/test.csv')
df_testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10194 non-null  int64
#  1   clonesize             10194 non-null  float64
#  2   honeybee              10194 non-null  float64
#  3   bumbles               10194 non-null  float64
#  4   andrena               10194 non-null  float64
#  5   osmia                 10194 non-null  float64
#  6   MaxOfUpperTRange      10194 non-null  float64
#  7   MinOfUpperTRange      10194 non-null  float64
#  8   AverageOfUpperTRange  10194 non-null  float64
#  9   MaxOfLowerTRange      10194 non-null  float64
#  10  MinOfLowerTRange      10194 non-null  float64
#  11  AverageOfLowerTRange  10194 non-null  float64
#  12  RainingDays           10194 non-null  float64
#  13  AverageRainingDays    10194 non-null  float64
# ...

# %%
df_testing['clonesize_encoded'] = df_testing['clonesize']
df_testing['clonesize_encoded'] = np.where((df_testing['clonesize_encoded'] >= 0) & (df_testing['clonesize_encoded'] <= 15), 1, df_testing['clonesize_encoded'])
df_testing['clonesize_encoded'] = np.where((df_testing['clonesize_encoded'] > 15) & (df_testing['clonesize_encoded'] <= 25), 2, df_testing['clonesize_encoded'])
df_testing['clonesize_encoded'] = np.where((df_testing['clonesize_encoded'] > 25) & (df_testing['clonesize_encoded'] <= 35), 3, df_testing['clonesize_encoded'])
df_testing['clonesize_encoded'] = np.where((df_testing['clonesize_encoded'] > 35), 4, df_testing['clonesize_encoded'])
df_testing['total_honeybee'] = df_testing['clonesize'] * df_testing['honeybee']
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)
df_testing['pca_density'] = pca.fit_transform(df_testing[['honeybee', 'bumbles', 'andrena', 'osmia']])
# Binning the AverageOfUpperTRange feature
df_testing['AverageOfUpperTRange_encoded'] = df_testing['AverageOfUpperTRange']
bins = [0, 60, 67, 75, 80]
labels = [1, 2, 3, 4]
df_testing['AverageOfUpperTRange_encoded'] = pd.cut(df_testing['AverageOfUpperTRange_encoded'], bins = bins, labels = labels)
# Binning the AverageOfLowerTRange feature
df_testing['AverageOfLowerTRange_encoded'] = df_testing['AverageOfLowerTRange']
bins = [0, 42, 48, 52, 59]
labels = [1, 2, 3, 4]
df_testing['AverageOfLowerTRange_encoded'] = pd.cut(df_testing['AverageOfLowerTRange_encoded'], bins = bins, labels = labels)
# Binning the rainy days
bins = [0, 10, 20, 30, 40]
labels = [1, 2, 3, 4]
df_testing['RainingDays_encoded'] = pd.cut(df_testing['RainingDays'], bins = bins, labels = labels)
df_testing['fruitset_encoded'] = round(df_testing['fruitset'], 3)
df_testing['fruitmass_encoded'] = round(df_testing['fruitmass'], 3)
df_testing['seeds_encoded'] = round(df_testing['seeds'], 3)
# df_testing['yield_encoded'] = round(df_testing['yield'], 3)

# %%
df_testing
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0      15289       25.0      0.25     0.25     0.25   0.25              86.0
# 1      15290       12.5      0.25     0.25     0.75   0.63              94.6
# 2      15291       12.5      0.25     0.25     0.63   0.63              86.0
# 3      15292       25.0      0.50     0.38     0.38   0.63              86.0
# 4      15293       37.5      0.75     0.25     0.25   0.25              94.6
# ...      ...        ...       ...      ...      ...    ...               ...
# 10189  25478       25.0      0.25     0.25     0.25   0.25              86.0
# 10190  25479       25.0      0.50     0.25     0.50   0.75              77.4
# 10191  25480       25.0      0.50     0.38     0.50   0.50              77.4
# 10192  25481       12.5      0.25     0.25     0.38   0.50              94.6
# 10193  25482       12.5      0.25     0.25     0.50   0.50              77.4
#
# ...

# %%
X_testing = df_testing[[
    'seeds_encoded',
    'fruitmass_encoded',
    'fruitset_encoded',
    'AverageOfLowerTRange_encoded',
    'AverageOfUpperTRange_encoded',
    'pca_density',
    'clonesize_encoded',
    'AverageRainingDays'
]]

# %%
X_testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   seeds_encoded                 10194 non-null  float64
#  1   fruitmass_encoded             10194 non-null  float64
#  2   fruitset_encoded              10194 non-null  float64
#  3   AverageOfLowerTRange_encoded  10194 non-null  category
#  4   AverageOfUpperTRange_encoded  10194 non-null  category
#  5   pca_density                   10194 non-null  float64
#  6   clonesize_encoded             10194 non-null  float64
#  7   AverageRainingDays            10194 non-null  float64
# dtypes: category(2), float64(6)
# memory usage: 498.3 KB

# %%
output = pd.DataFrame({'id' : df_testing['id'], 'yield' : model.predict(X_testing)})
output.to_csv('submission.csv', index = False)

# %%
from google.colab import files
files.download('submission.csv')
